# %%
import pandas as pd

df = pd.read_csv("../data/hydrated_data_ieee/final_data/shallow_processed_with_prediction.csv")
# Out:
# /Library/Python/3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (22) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]

# %%
df
# Out:
#            tweet_id                                               text  \
# 0      1.240728e+18        holy shit I hate every person in this video
# 1      1.240728e+18  There you have it.\n\nProof that this is an in...
# 2      1.240728e+18  Among other things, what this shows is they're...
# 3      1.240729e+18                    this incompetent racist asshole
# 4      1.240729e+18  Among other things, what this shows is they're...
# ...             ...                                                ...
# 52337  1.267310e+18  COVID-19 has a 2-14 day incubation period. If ...
# 52338  1.267311e+18  First they burned down our economy, impoverish...
# 52339  1.267311e+18  Fears about COVID-19 can take an emotional tol...
# 52340  1.267311e+18                              Not the seafood tho 😂
# 52341  1.267312e+18  I said Nick Cannon has Lupus and is still prot...
#
#        retweet_count  favorite_count possibly_sensitive withheld_in_countries  \
# ...

# %%
import demoji
demoji.download_codes()
# Out:
# ...
# ... OK (Got response in 0.33 seconds)
# Writing emoji data to /Users/tingfengx/.demoji/codes.json ...
# ... OK

# %%
def check_contains_emoji(text):
    if not isinstance(text, str): # handle NaN
        return False
    else:
        def deEmojify(inputString):
#             print(inputString, type(inputString))
#             raise Exception()
            return inputString.encode('ascii', 'ignore').decode('ascii')
        return deEmojify(text) != text

# %%
df["username_contains_emoji"] = df["user.name"].map(check_contains_emoji)
# Out:
# /Library/Python/3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df["userscreenname_contains_emoji"] = df["user.screen_name"].map(check_contains_emoji)
# Out:
# /Library/Python/3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df["userdescription_contains_emoji"] = df["user.description"].map(check_contains_emoji)

# %%
df
# Out:
#            tweet_id                                               text  \
# 0      1.240728e+18        holy shit I hate every person in this video
# 1      1.240728e+18  There you have it.\n\nProof that this is an in...
# 2      1.240728e+18  Among other things, what this shows is they're...
# 3      1.240729e+18                    this incompetent racist asshole
# 4      1.240729e+18  Among other things, what this shows is they're...
# ...             ...                                                ...
# 52337  1.267310e+18  COVID-19 has a 2-14 day incubation period. If ...
# 52338  1.267311e+18  First they burned down our economy, impoverish...
# 52339  1.267311e+18  Fears about COVID-19 can take an emotional tol...
# 52340  1.267311e+18                              Not the seafood tho 😂
# 52341  1.267312e+18  I said Nick Cannon has Lupus and is still prot...
#
#        retweet_count  favorite_count possibly_sensitive withheld_in_countries  \
# ...

# %%
df.to_csv("../data/hydrated_data_ieee/final_data/shallow_processed_with_prediction.csv")
